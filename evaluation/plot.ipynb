# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# remember: evaluation_id is not unique -> can't use as index
df = pd.read_json('./resources/results.json')
df
# Out:
#    evaluation_id                activity assistant  \
# 0              1  vulnerability_research   default
# 1              2  vulnerability_research   default
# 2              3  vulnerability_research   default
# 3              4  vulnerability_research   default
# 4              5           code_analysis   default
# 5              1  vulnerability_research   default
#
#                            model    metric_name  score  \
# 0  mistral:7b-instruct-v0.3-q8_0  hallucination      0
# 1  mistral:7b-instruct-v0.3-q8_0  hallucination      1
# 2  mistral:7b-instruct-v0.3-q8_0  hallucination      1
# 3  mistral:7b-instruct-v0.3-q8_0  hallucination      1
# 4  mistral:7b-instruct-v0.3-q8_0  hallucination      1
# 5                      gemma2:9b  hallucination      1
#
#                                               reason  \
# 0  The score is 0.00 because the actual output al...
# 1  The score is 1.00 because the actual output co...
# ...

# %%
idx = 5
print('reason: ', df.loc[idx, 'reason'])
df.loc[idx, 'conversation']
# Out:
# reason:  The score is 1.00 because the actual output contradicts the provided context by not confirming or denying the specific vulnerabilities mentioned, instead offering general advice.
# {'conversation_id': 0,
#  'name': 'JetBrains_TeamCity_RCE',
#  'messages': [{'role': 'system',
#    'content': '# Role\n\nAs a proficient ethical hacker, your primary goal is to assist the user by providing actionable guidance in ethical hacking activities.\n\n## Instructions\n\nWhen the user message includes additional information under the "# CONTEXT" header, integrate that content into your overall understanding. Use it as an extension of your own knowledge and do not reference or disclose that it was provided separately. Your responses should appear unified and natural, without phrases like "based on the provided text" or any indication that the extra context came from an external source.\n',
#    'token_length': 0},
#   {'role': 'user',
# ...
